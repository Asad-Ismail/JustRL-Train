# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "nvidia/OpenMath-Nemotron-1.5B"
# Out:
# Running cells with '.venv (Python 3.12.9)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/sagemaker-user/JustRL-Train/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
